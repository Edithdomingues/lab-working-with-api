# %% [markdown]
# ## Lab 1 | Web Scraping Single Page

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.billboard.com/charts/hot-100/"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#Title
titles = []
for title in soup.select("#title-of-a-story")[3:103]:
    titles.append(title.get_text().strip())
    
# Artist
artists = []
for artist in soup.select("li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.u-border-b-0\@mobile-max.lrv-u-border-color-grey-light.lrv-u-padding-l-1\@mobile-max > span"):
    artists.append(artist.get_text().strip())
    
top100 = pd.DataFrame({'artist':artists,'title':titles})

# %%
top100.head(60)
# Out:
#                                                artist  \
# 0                                        Taylor Swift
# 1                                               Adele
# 2                       The Kid LAROI & Justin Bieber
# 3                             Lil Nas X & Jack Harlow
# 4            Silk Sonic (Bruno Mars & Anderson .Paak)
# 5                                          Ed Sheeran
# 6                                          Ed Sheeran
# 7                                       Glass Animals
# 8                                            Doja Cat
# 9                                        Walker Hayes
# 10                              Elton John & Dua Lipa
# 11                Drake Featuring Future & Young Thug
# 12                                     Olivia Rodrigo
# 13                              Doja Cat & The Weeknd
# 14              Wizkid Featuring Justin Bieber & Tems
# 15                                           Maneskin
# 16                                           Dua Lipa
# 17                                       Taylor Swift
# 18                           Post Malone & The Weeknd
# 19                                         Juice WRLD
# 20                             Doja Cat Featuring SZA
# 21             Taylor Swift Featuring Chris Stapleton
# 22           Silk Sonic (Bruno Mars & Anderson .Paak)
# 23                    Jason Aldean & Carrie Underwood
# 24                                       Taylor Swift
# 25                         The Weeknd & Ariana Grande
# 26            Drake Featuring 21 Savage & Project Pat
# 27                   THE ANXIETY: WILLOW & Tyler Cole
# 28                       NEIKED X Mae Muller X Polo G
# 29  Dustin Lynch Featuring Lauren Alaina Or MacKen...
# 30                           Drake Featuring Lil Baby
# 31                                         Luke Combs
# 32                                      Justin Bieber
# 33                                               CKay
# 34                        Ryan Hurd With Maren Morris
# 35                                       Mariah Carey
# 36                                     Coldplay x BTS
# 37                  Jordan Davis Featuring Luke Bryan
# 38                                          Lil Nas X
# 39                                      Billie Eilish
# 40                                            Farruko
# 41                                    Chris Stapleton
# 42             Taylor Swift Featuring Phoebe Bridgers
# 43  Nardo Wick Featuring G Herbo, Lil Durk & 21 Sa...
# 44                                       Taylor Swift
# 45                                       Taylor Swift
# 46                  Taylor Swift Featuring Ed Sheeran
# 47                                          Lil Nas X
# 48                                             Polo G
# 49                                     Zac Brown Band
# 50                                       Taylor Swift
# 51                                       Taylor Swift
# 52                                         Luke Combs
# 53                                       Taylor Swift
# 54                                       Taylor Swift
# 55                                Summer Walker & SZA
# 56                          Normani Featuring Cardi B
# 57                                              Chloe
# 58                                       Taylor Swift
# 59               Blxst & Tyga Featuring Ty Dolla $ign
#
#                                                 title
# 0                     All Too Well (Taylor's Version)
# 1                                          Easy On Me
# 2                                                Stay
# 3                                       Industry Baby
# 4                               Smokin Out The Window
# 5                                          Bad Habits
# 6                                             Shivers
# 7                                          Heat Waves
# 8                                        Need To Know
# 9                                          Fancy Like
# 10                            Cold Heart (PNAU Remix)
# 11                                         Way 2 Sexy
# 12                                           Good 4 U
# 13                                          You Right
# 14                                            Essence
# 15                                            Beggin'
# 16                                         Levitating
# 17                  State Of Grace (Taylor's Version)
# 18                                      One Right Now
# 19                                       Already Dead
# 20                                       Kiss Me More
# 21  I Bet You Think About Me (Taylor's Version) (F...
# 22                                Leave The Door Open
# 23                               If I Didn't Love You
# 24                             Red (Taylor's Version)
# 25                                    Save Your Tears
# 26                                         Knife Talk
# 27                                Meet Me At Our Spot
# 28                                        Better Days
# 29                                 Thinking 'Bout You
# 30                                   Girls Want Girls
# 31                                        Cold As You
# 32                                              Ghost
# 33                           Love Nwantiti (Ah Ah Ah)
# 34                                  Chasing After You
# 35                    All I Want For Christmas Is You
# 36                                        My Universe
# 37                                           Buy Dirt
# 38                                  Thats What I Want
# 39                                  Happier Than Ever
# 40                                              Pepas
# 41                          You Should Probably Leave
# 42    Nothing New (Taylor's Version) (From The Vault)
# 43                                   Who Want Smoke??
# 44  Message In A Bottle (Taylor's Version) (From T...
# 45         I Knew You Were Trouble (Taylor's Version)
# 46            Run (Taylor's Version) (From The Vault)
# 47                     Montero (Call Me By Your Name)
# 48                          Bad Man (Smooth Criminal)
# 49                                          Same Boat
# 50     Better Man (Taylor's Version) (From The Vault)
# 51                              22 (Taylor's Version)
# 52                                         Doin' This
# 53                     Treacherous (Taylor's Version)
# 54  We Are Never Ever Getting Back Together (Taylo...
# 55                                            No Love
# 56                                          Wild Side
# 57                                         Have Mercy
# 58                     I Almost Do (Taylor's Version)
# 59                                             Chosen

# %% [markdown]
# ## Lab 2 | Web Scraping Multiple Pages

# %%
# PopVortex iTunes Top100 USA

# %%
url = 'http://www.popvortex.com/music/charts/top-100-songs.php'

# %%
response = requests.get(url)
display(url,response.status_code)
# Out:
# 'http://www.popvortex.com/music/charts/top-100-songs.php'
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#Title
titles = []
for title in soup.select("cite.title"):
    titles.append(title.get_text())
    
# Artist
artists = []
for artist in soup.select("em.artist"):
    artists.append(artist.get_text())
    
top100vortex = pd.DataFrame({'artist':artists,'title':titles})
top100vortex.head(60)
# Out:
#                                      artist  \
# 0                                     Adele
# 1               State of Mine & Drew Jacobs
# 2                     Elton John & Dua Lipa
# 3                              Walker Hayes
# 4                                  Kid Rock
# 5                                Ed Sheeran
# 6                                     GAYLE
# 7                                 Emmy Meli
# 8                              Walker Hayes
# 9                            Girl Named Tom
# 10                           Jennifer Lopez
# 11                                 Måneskin
# 12                 Shane Smith & the Saints
# 13                           Girl Named Tom
# 14                                    Adele
# 15          Jason Aldean & Carrie Underwood
# 16  Bruno Mars, Anderson .Paak & Silk Sonic
# 17                 Post Malone & The Weeknd
# 18                                    Adele
# 19                     Jimmie Allen & Nelly
# 20                             Mariah Carey
# 21         THE ANXIETY, WILLOW & Tyler Cole
# 22                               Luke Combs
# 23                             Jordan Davis
# 24                             Jason Aldean
# 25                              Tyson James
# 26                                    Adele
# 27                 Trans-Siberian Orchestra
# 28                               Brenda Lee
# 29                             Walker Hayes
# 30                            Glass Animals
# 31                                    Adele
# 32                           Coldplay X BTS
# 33                  Lil Nas X & Jack Harlow
# 34                          Chris Stapleton
# 35              Jimmie Allen & Brad Paisley
# 36                             Cody Johnson
# 37                            Justin Bieber
# 38                                   Acraze
# 39             Robert Plant & Alison Krauss
# 40                                    Adele
# 41                               Ed Sheeran
# 42                           Olivia Rodrigo
# 43                             Taylor Swift
# 44                           Casting Crowns
# 45                            Blake Shelton
# 46                            Morgan Wallen
# 47                                    Latto
# 48                        The Band McMillan
# 49                                    Adele
# 50                                      BTS
# 51                 Ryan Hurd & Maren Morris
# 52                                    Adele
# 53                               Kane Brown
# 54            Carly Pearce & Ashley McBryde
# 55                          Chris Stapleton
# 56                         Carrie Underwood
# 57                            Ariana Grande
# 58                                    Adele
# 59                             Taylor Swift
#
#                                               title
# 0                                        Easy On Me
# 1                                     God's Country
# 2                           Cold Heart (PNAU Remix)
# 3                                        Fancy Like
# 4   Don't Tell Me How To Live (feat. Monster Truck)
# 5                                           Shivers
# 6                                           abcdefu
# 7                                        I AM WOMAN
# 8                                                AA
# 9                             More Hearts Than Mine
# 10                             On My Way (Marry Me)
# 11                                           Beggin
# 12                                 All I See Is You
# 13         Dust In The Wind (The Voice Performance)
# 14                                     I Drink Wine
# 15                             If I Didn't Love You
# 16                            Smokin Out The Window
# 17                                    One Right Now
# 18                                      To Be Loved
# 19                                  Good Times Roll
# 20                  All I Want For Christmas Is You
# 21                       Meet Me At Our Spot (Live)
# 22                                       Doin' This
# 23                      Buy Dirt (feat. Luke Bryan)
# 24                                           Heaven
# 25                                      Rittenhouse
# 26                                          Hold On
# 27        Christmas / Sarajevo 12/24 (Instrumental)
# 28       Rockin' Around the Christmas Tree (Single)
# 29                                           U Gurl
# 30                                       Heat Waves
# 31                                        Oh My God
# 32                                      My Universe
# 33                                    INDUSTRY BABY
# 34                        You Should Probably Leave
# 35                            Freedom Was A Highway
# 36                                   'Til You Can't
# 37                                            Ghost
# 38                      Do It To It (feat. Cherish)
# 39                                     Can't Let Go
# 40                                            Hello
# 41                                       Bad Habits
# 42                                          traitor
# 43                                        Enchanted
# 44                                  Scars in Heaven
# 45                       Come Back As A Country Boy
# 46                                 Sand In My Boots
# 47                                       Big Energy
# 48                                Somebody's Got To
# 49                                     Can I Get It
# 50                                           Butter
# 51                                Chasing After You
# 52                              Rolling in the Deep
# 53                                  One Mississippi
# 54                     Never Wanted To Be That Girl
# 55                                Tennessee Whiskey
# 56                                   Stretchy Pants
# 57                                    Santa Tell Me
# 58                            Make You Feel My Love
# 59                  All Too Well (Taylor's Version)

# %%
# Apple Music Top100 Global

# %%
url = 'https://music.apple.com/us/playlist/top-100-global/pl.d25f5d1181894928af76c85c967f8f31'

# %%
response = requests.get(url)
display(url,response.status_code)
# Out:
# 'https://music.apple.com/us/playlist/top-100-global/pl.d25f5d1181894928af76c85c967f8f31'
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#Artist

soup.select("div.songs-list-row__by-line")[0].get_text().strip()
# Out:
# 'Adele'

# %%
#Title

soup.select("div.songs-list-row__song-wrapper > div > div.songs-list-row__song-name")[0].get_text()
# Out:
# 'Easy On Me'

# %%
#Title

titles = []
for title in soup.select("div.songs-list__col.songs-list__col--song.typography-body > div > div.songs-list-row__song-wrapper > div"):
    titles.append(title.get_text().strip())
    
# Artist

artists = []
for artist in soup.select("div.songs-list-row__by-line"):
    artists.append(artist.get_text().strip())
    
top100apple = pd.DataFrame({'artist':artists,'title':titles})
top100apple['title'] = top100apple['title'].apply(lambda x: x.split("\n")[0])
top100apple.head(60)
# Out:
#                                         artist  \
# 0                                        Adele
# 1                                        Adele
# 2                                        Adele
# 3                                        Adele
# 4                                        Adele
# 5                                        Adele
# 6                                        Adele
# 7               The Kid LAROI &  Justin Bieber
# 8                                        Adele
# 9                                        Adele
# 10                                       Adele
# 11                                       Adele
# 12                                Taylor Swift
# 13                                       Drake
# 14  Bruno Mars,  Anderson .Paak, &  Silk Sonic
# 15                                  Ed Sheeran
# 16                                       Adele
# 17                    Lil Nas X &  Jack Harlow
# 18                                       Drake
# 19                        Summer Walker &  SZA
# 20                                  Ed Sheeran
# 21                               Glass Animals
# 22                                  Nardo Wick
# 23                                Mariah Carey
# 24                                    Doja Cat
# 25                                       Drake
# 26                       Amaarae &  Kali Uchis
# 27                   Post Malone &  The Weeknd
# 28                      Elton John &  Dua Lipa
# 29                                       Yuuri
# 30                                 Kodak Black
# 31              NEIKED,  Mae Muller, &  Polo G
# 32                                       GAYLE
# 33                            Macaroni Empitsu
# 34                               Billie Eilish
# 35                                       Drake
# 36  Bruno Mars,  Anderson .Paak, &  Silk Sonic
# 37                                     Farruko
# 38                                  Juice WRLD
# 39                    Summer Walker &  Cardi B
# 40                                 back number
# 41                                      Polo G
# 42                                    Doja Cat
# 43                               Summer Walker
# 44                                Taylor Swift
# 45                                       Yuuri
# 46                               Summer Walker
# 47                                  Young Thug
# 48                                Taylor Swift
# 49                                 Young Dolph
# 50                               Summer Walker
# 51                               Summer Walker
# 52                                   Meek Mill
# 53                                Taylor Swift
# 54                                Taylor Swift
# 55           Summer Walker,  JT, &  City Girls
# 56                                  The Weeknd
# 57                                Taylor Swift
# 58                                       Drake
# 59                                         BTS
#
#                                                 title
# 0                                          Easy On Me
# 1                                           Oh My God
# 2                                      My Little Love
# 3                                        I Drink Wine
# 4                                 Strangers By Nature
# 5                                        Can I Get It
# 6                                  Cry Your Heart Out
# 7                                                STAY
# 8                                         To Be Loved
# 9                                             Hold On
# 10                                      Woman Like Me
# 11   All Night Parking (with Erroll Garner) Interlude
# 12  All Too Well (10 Minute Version) (Taylor's Ver...
# 13         Knife Talk (feat. 21 Savage & Project Pat)
# 14                              Smokin Out The Window
# 15                                            Shivers
# 16                                     Love Is A Game
# 17                                      INDUSTRY BABY
# 18             Way 2 Sexy (feat. Future & Young Thug)
# 19                                            No Love
# 20                                         Bad Habits
# 21                                         Heat Waves
# 22  Who Want Smoke?? (feat. G Herbo, Lil Durk & 21...
# 23                    All I Want For Christmas Is You
# 24                                       Need To Know
# 25                  Girls Want Girls (feat. Lil Baby)
# 26            Sad Girlz Luv Money Remix (feat. Moliy)
# 27                                      One Right Now
# 28                            Cold Heart (PNAU Remix)
# 29                                         BETELGEUSE
# 30                                      Super Gremlin
# 31                                        Better Days
# 32                                            abcdefu
# 33                                     Nanndemonaiyo,
# 34                                  Happier Than Ever
# 35                    Fair Trade (feat. Travis Scott)
# 36                                Leave The Door Open
# 37                                              Pepas
# 38                                       Already Dead
# 39                      Bitter (Narration By Cardi B)
# 40                                          Suiheisen
# 41                          Bad Man (Smooth Criminal)
# 42                           Kiss Me More (feat. SZA)
# 43                                             Insane
# 44                                          Enchanted
# 45                                       Dried Flower
# 46                                      Throw It Away
# 47                 Bubbly (with Drake & Travis Scott)
# 48                    All Too Well (Taylor's Version)
# 49                                          100 Shots
# 50                                        Reciprocate
# 51                             Toxic (feat. Lil Durk)
# 52      Sharing Locations (feat. Lil Baby & Lil Durk)
# 53  I Bet You Think About Me (Taylor's Version) (F...
# 54                             Red (Taylor's Version)
# 55                                    Ex For A Reason
# 56                                    Blinding Lights
# 57  Run (Taylor's Version) (From The Vault) [feat....
# 58             In The Bible (feat. Lil Durk & GIVĒON)
# 59                                             Butter

# %%
# 4 Decades between 1980 - 2010
# TSORT Top100 by decade

# %%
url2010 = 'http://tsort.info/music/ds2010.htm'
url2000 = 'http://tsort.info/music/ds2000.htm'
url1990 = 'http://tsort.info/music/ds1990.htm'
url1980 = 'http://tsort.info/music/ds1980.htm'

# %%
for url in [url2010, url2000,url1990,url1980]:
    response = requests.get(url)
    display(url,response.status_code)
# Out:
# 'http://tsort.info/music/ds2010.htm'
# 200
# 'http://tsort.info/music/ds2000.htm'
# 200
# 'http://tsort.info/music/ds1990.htm'
# 200
# 'http://tsort.info/music/ds1980.htm'
# 200

# %%
soup2010 = BeautifulSoup(requests.get(url2010).content, "html.parser")
soup2000 = BeautifulSoup(requests.get(url2000).content, "html.parser")
soup1990 = BeautifulSoup(requests.get(url1990).content, "html.parser")
soup1980 = BeautifulSoup(requests.get(url1980).content, "html.parser")

# %%
#1980
artists = []
titles = []
years = []

for artist in soup1980.select("td.art"): #Artist
    artists.append(artist.get_text())
    
for title in soup1980.select("td.tit"): #Title
    titles.append(title.get_text())
    
for year in soup1980.select("td.yer"): #Year
    years.append(year.get_text())

year1980 = pd.DataFrame({'artist':artists, 'title':titles, 'year':years})

# %%
#1990
artists = []
titles = []
years = []

for artist in soup1990.select("td.art"): #Artist
    artists.append(artist.get_text())
    
for title in soup1990.select("td.tit"): #Title
    titles.append(title.get_text())
    
for year in soup1990.select("td.yer"): #Year
    years.append(year.get_text())

year1990 = pd.DataFrame({'artist':artists, 'title':titles, 'year':years})

# %%
#2000
artists = []
titles = []
years = []

for artist in soup2000.select("td.art"): #Artist
    artists.append(artist.get_text())
    
for title in soup2000.select("td.tit"): #Title
    titles.append(title.get_text())
    
for year in soup2000.select("td.yer"): #Year
    years.append(year.get_text())

year2000 = pd.DataFrame({'artist':artists, 'title':titles, 'year':years})

# %%
#2010
artists = []
titles = []
years = []

for artist in soup2010.select("td.art"): #Artist
    artists.append(artist.get_text())
    
for title in soup2010.select("td.tit"): #Title
    titles.append(title.get_text())
    
for year in soup2010.select("td.yer"): #Year
    years.append(year.get_text())

year2010 = pd.DataFrame({'artist':artists, 'title':titles, 'year':years})

# %%
top100_80s_10s = pd.concat([year1980,year1990,year2000,year2010], axis = 0)

# %%
top100_80s_10s.head(60)
# Out:
#                             artist  \
# 0                       Pink Floyd
# 1                       Irene Cara
# 2                       Kim Carnes
# 3                       The Police
# 4                  Michael Jackson
# 5                    Stevie Wonder
# 6                   USA For Africa
# 7                   George Michael
# 8                         Survivor
# 9                          Madonna
# 10                Barbra Streisand
# 11     Joan Jett & The Blackhearts
# 12                    Culture Club
# 13                    Phil Collins
# 14                     John Lennon
# 15                          Prince
# 16                    Culture Club
# 17                      Diana Ross
# 18                 Whitney Houston
# 19                            A-Ha
# 20                         Blondie
# 21                     Rick Astley
# 22  Paul McCartney & Stevie Wonder
# 23                 Michael Jackson
# 24                       Starsound
# 25              Olivia Newton-John
# 26                          Berlin
# 27                The Human League
# 28                       Los Lobos
# 29                           Falco
# 30                        Band Aid
# 31                       Foreigner
# 32        Dionne Warwick & Friends
# 33                       Lipps Inc
# 34                     Tina Turner
# 35                    Cyndi Lauper
# 36                     David Bowie
# 37       Frankie Goes To Hollywood
# 38      Diana Ross & Lionel Richie
# 39                  George Michael
# 40               Steve Miller Band
# 41                         Madonna
# 42                 Tears For Fears
# 43                           Queen
# 44                              U2
# 45                     The Bangles
# 46                       Soft Cell
# 47                    J Geils Band
# 48                           Wham!
# 49               The Pet Shop Boys
# 50                    Phil Collins
# 51                    Bonnie Tyler
# 52                   Lionel Richie
# 53   Bill Medley & Jennifer Warnes
# 54                  Bobby McFerrin
# 55            Fine Young Cannibals
# 56                   Lionel Richie
# 57                         Roxette
# 58                            UB40
# 59                     The Bangles
#
#                                          title  year
# 0           Another Brick in the Wall (part 2)  1980
# 1                 Flashdance... What a Feeling  1983
# 2                             Bette Davis Eyes  1981
# 3                        Every Breath You Take  1983
# 4                                  Billie Jean  1983
# 5              I Just Called to Say I Love You  1984
# 6                             We Are the World  1985
# 7                             Careless Whisper  1984
# 8                             Eye of the Tiger  1982
# 9                                Like a Prayer  1989
# 10                             A Woman in Love  1980
# 11                        I Love Rock 'n' Roll  1982
# 12                             Karma Chameleon  1983
# 13                     Another Day in Paradise  1989
# 14                   (Just Like) Starting Over  1980
# 15                              When Doves Cry  1984
# 16              Do You Really Want to Hurt Me?  1982
# 17                                 Upside Down  1980
# 18  I Wanna Dance With Somebody (Who Loves Me)  1987
# 19                                  Take On Me  1985
# 20                                     Call Me  1980
# 21                     Never Gonna Give You Up  1987
# 22                               Ebony & Ivory  1982
# 23                                     Beat It  1983
# 24                                 Stars On 45  1981
# 25                        (Let's Get) Physical  1981
# 26                         Take My Breath Away  1986
# 27                           Don't You Want Me  1982
# 28                                    La Bamba  1987
# 29                             Rock Me Amadeus  1986
# 30                Do They Know It's Christmas?  1984
# 31                 I Want to Know What Love Is  1985
# 32                 That's What Friends Are For  1986
# 33                                   Funkytown  1980
# 34              What's Love Got to Do With It?  1984
# 35                   Girls Just Wanna Have Fun  1984
# 36                                 Let's Dance  1983
# 37                                       Relax  1984
# 38                                Endless Love  1981
# 39                                       Faith  1987
# 40                                 Abracadabra  1982
# 41                           Papa Don't Preach  1986
# 42                                       Shout  1985
# 43                  Another One Bites the Dust  1980
# 44                         With Or Without You  1987
# 45                       Walk Like an Egyptian  1986
# 46                                Tainted Love  1981
# 47                                  Centrefold  1982
# 48                 Wake Me Up Before You Go Go  1984
# 49                              West End Girls  1986
# 50                       A Groovy Kind of Love  1988
# 51                  Total Eclipse of the Heart  1983
# 52                             Say You, Say Me  1985
# 53              (I've Had) the Time of My Life  1987
# 54                        Don't Worry Be Happy  1988
# 55                         She Drives Me Crazy  1989
# 56                  All Night Long (All Night)  1983
# 57                                    The Look  1989
# 58                                Red Red Wine  1983
# 59                               Eternal Flame  1989

# %% [markdown]
# ## Lab | Working with APIs

# %%
import pandas as pd
import requests
import json

# %%
res1 = requests.get('https://axoltlapi.herokuapp.com/')

# %%
type(res1)
# Out:
# requests.models.Response

# %%
data1 = res1.json()
data1
# Out:
# {'url': 'https://i.imgur.com/O74dUFG.jpg',
#  'facts': 'Our species is named after the Aztec god Xolotl.',
#  'pics_repo': 'https://github.com/AxolotlAPI/data',
#  'api_repo': 'https://github.com/AxolotlAPI/axolotl.py-api'}

# %%
res = requests.get('https://dog-facts-api.herokuapp.com/api/v1/resources/dogs/all')

# %%
type(res)
# Out:
# requests.models.Response

# %%
#data
data = res.json()

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                   fact
# 0    All dogs can be traced back 40 million years a...
# 1    Ancient Egyptians revered their dogs. When a p...
# 2    Small quantities of grapes and raisins can cau...
# 3    Apple and pear seeds contain arsenic, which ma...
# 4    Rock star Ozzy Osborne saved his wife Sharon’s...
# ..                                                 ...
# 430  Dogs can discriminate the emotional expression...
# 431   The largest breed of dog is the Irish Wolfhound.
# 432  Dogs do not have an appendix. Why haven’t huma...
# 433         Dogs are all direct descendants of wolves.
# 434  A dog’s heart beats up to 120 times per minute...
#
# [435 rows x 1 columns]

# %%
flattened_data = pd.json_normalize(data)
flattened_data
print(flattened_data['fact'][1])
# Out:
# Ancient Egyptians revered their dogs. When a pet dog would die, the owners shaved off their eyebrows, smeared mud in their hair, and mourned aloud for days.

# %%
import random

def random_catfact(data):
    print(data['text'][random.randint(0, len(data)-1)])

# %%
#data.shape

response = requests.get('https://dog-facts-api.herokuapp.com/api/v1/resources/dogs/all')

data = pd.DataFrame(response.json())
data.head()
# Out:
#                                                 fact
# 0  All dogs can be traced back 40 million years a...
# 1  Ancient Egyptians revered their dogs. When a p...
# 2  Small quantities of grapes and raisins can cau...
# 3  Apple and pear seeds contain arsenic, which ma...
# 4  Rock star Ozzy Osborne saved his wife Sharon’s...

# %%
res2 = requests.get('https://anapioficeandfire.com/api/characters/583')

# %%
type(res2)
# Out:
# requests.models.Response

# %%
#data 2
data2 = res2.json()

# %%
from pandas.io.json import json_normalize

results = res2.json()
flattened_data = json_normalize(results)

flattened_data
# Out:
# <ipython-input-44-14c44ba216e6>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#                                                 url      name gender  \
# 0  https://anapioficeandfire.com/api/characters/583  Jon Snow   Male
#
#     culture       born died                                 titles  \
# 0  Northmen  In 283 AC       [Lord Commander of the Night's Watch]
#
#                                              aliases father mother spouse  \
# 0  [Lord Snow, Ned Stark's Bastard, The Snow of W...
#
#                                       allegiances  \
# 0  [https://anapioficeandfire.com/api/houses/362]
#
#                                          books  \
# 0  [https://anapioficeandfire.com/api/books/5]
#
#                                             povBooks  \
# 0  [https://anapioficeandfire.com/api/books/1, ht...
#
#                                             tvSeries         playedBy
# 0  [Season 1, Season 2, Season 3, Season 4, Seaso...  [Kit Harington]

# %%
flattened_data = pd.json_normalize(data2)
flattened_data
print(flattened_data['name'][0])
# Out:
# Jon Snow

# %%
# df2 = pd.DataFrame(data2)
# df2

# %%
res21 = requests.get('https://api.corrently.io/core/gsi?key=[APIKEY]')

# %%
type(res21)
# Out:
# requests.models.Response

# %%
#data 21 
data21 = res21.json()

# %%
from pandas.io.json import json_normalize

results = res21.json()
flattened_data = json_normalize(results)

flattened_data
# Out:
# <ipython-input-50-e9bf902d1a18>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#                                             forecast location.zip  \
# 0  [{'epochtime': 1637708400, 'eevalue': 42, 'ewi...        10117
#
#   location.city  matrix.h_0.timeStamp  matrix.h_0.avg_1  matrix.h_0.avg_2  \
# 0        Berlin         1637708400000             False             False
#
#    matrix.h_0.avg_3  matrix.h_0.avg_4  matrix.h_0.avg_5  matrix.h_0.avg_6  \
# 0             False             False             False             False
#
#    ...  matrix.h_46.avg_10  matrix.h_46.avg_9  matrix.h_46.avg_8  \
# 0  ...                  49                 49                 49
#
#    matrix.h_46.avg_7  matrix.h_46.avg_6  matrix.h_46.avg_5  matrix.h_46.avg_4  \
# 0                 49                 49                 49                 48
#
#    matrix.h_46.avg_3  matrix.h_46.avg_2  matrix.h_46.avg_1
# 0                 48                 48                 48
#
# [1 rows x 2212 columns]

# %%
flattened_data = pd.json_normalize(data21)
flattened_data
print(flattened_data['location.city'][0])
# Out:
# Berlin
